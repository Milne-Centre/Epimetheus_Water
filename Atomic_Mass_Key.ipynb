# %%
#data obtained from NIST
#https://physics.nist.gov/cgi-bin/Compositions/stand_alone.pl?ele=&all=all

element = {"H" : 1.00782503223, "H-1" : 1.00782503223, "H_err" : 0.00000000009, "H-1_err" : 0.00000000009,
           "H-2" : 2.01410177812, "D": 2.01410177812, "H-2_err" : 0.00000000012, "D_err" : 0.00000000012,
           "H-3" : 3.0160492779, "T": 3.0160492779, "H-3_err" : 0.0000000024, "T_err": 0.0000000024,
           "He-3" : 3.0160293201, "He-3_err" : 0.0000000025,
           "He" : 4.00260325413, "He-4" : 4.00260325413, "He_err" : 0.00000000006, "He-4_err" : 0.00000000006,
           "Li-3" :  6.0151228874, "Li-3_err" :  0.0000000016,
           "Li" :  7.0160034366, "Li-4" : 7.0160034366, "Li_err" : 0.0000000045, "Li-4_err" : 0.0000000045,
           "Be" :  9.012183065, "Be_err" :  0.000000082,
           "B-10" : 10.01293695, "B-10_err" : 0.00000041,
           "B" : 11.00930536, "B-11" : 11.00930536, "B_err" : 0.00000045, "B-11_err" : 0.00000045,
           "C" : 12.0, "C-12": 12.0, "C_err" : 0.0, "C-12_err": 0.0,
           "C-13" : 13.00335483507, "C-13_err" : 0.00000000023,
           "C-14" : 14.0032419884, "C-14" : 0.0000000040,
           "N" : 14.00307400443, "N-14" : 14.00307400443, "N_err" : 0.00000000020, "N-14_err" : 0.00000000020,
           "N-15" : 15.00010889888, "N-15_err": 0.00000000064,
           "O" : 15.99491461957, "O-16" : 15.99491461957, "O_err" : 0.00000000017, "O-16_err" : 0.00000000017,
           "O-17" : 16.99913175650, "O-17_err" : 0.00000000069,
           "O-18" : 17.99915961286, "O-18_err" : 0.00000000040, 
           "F" : 18.99840316273, "F_err" : 0.00000000092,
           "Na" : 22.9897692820, "Na_err" : 0.0000000019,
           "Mg" : 23.985041697, "Mg-24" : 23.985041697, "Mg_err"  :  0.000000014, "Mg-24_err"  :  0.000000014,
           "Mg-25" : 24.985836976, "Mg-25_err" : 0.000000050,
           "Mg-26" : 25.982592968, "Mg_err" : 0.000000031,
           "Al" : 26.98153853, "Al_err" : 0.00000011,
           "Si" : 27.97692653465, "Si-28" : 27.97692653465, "Si_err" : 0.00000000044, "Si-28_err" : 0.00000000044,
           "Si-29" : 28.97649466490, "Si-29_err" : 0.00000000052,
           "Si-30" : 29.973770136, "Si-30_err" : 0.000000023,
           "P" : 30.97376199842, "P_err" : 0.00000000070,
           "S" : 31.9720711744, "S-32" : 31.9720711744, "S_err" : 0.0000000014, "S-32_err": 0.0000000014,
           "S-33" : 32.9714589098, "S-33_err": 0.0000000015,
           "S-34" : 33.967867004, "S-34_err": 0.000000047, 
           "S-36" :35.96708071, "S-36_err": 0.00000020,
           "Cl" : 34.968852682, "Cl-35" : 34.968852682, "Cl_err" : 0.000000037, "Cl-35_err" : 0.000000037,
           "Cl-37" : 36.965902602, "Cl-37_err" : 0.000000055,
           "K" : 38.9637064864, "K-39" : 38.9637064864, "K_err" : 0.0000000049, "K-39_err" : 0.0000000049,
           "K-40" : 39.963998166, "K-40_err" : 0.000000060,
           "K-41" : 40.9618252579, "K-41_err" : 0.0000000041,
           "Ca" : 39.962590863, "Ca-40" : 39.962590863, "Ca_err" : 0.000000022, "Ca-40_err" : 0.000000022,
           "Ca-42" : 41.95861783, "Ca-42_err" : 0.00000016,
           "Ca-43" : 42.95876644, "Ca-43_err" : 0.00000024,
           "Ca-44" : 43.95548156, "Ca-44_err" : 0.00000035,
           "Ca-46" : 45.9536890, "Ca-46_err" : 0.0000024,
           "Ca-48" :  47.95252276, "Ca-48_err" :  0.00000013,
           "V-50" : 49.94715601, "V-50_err" : 0.00000095,
           "V" : 50.94395704, "V-51" : 50.94395704, "V_err" : 0.00000094, "V-51_err" : 0.00000094,
           "Cr-50" : 49.94604183, "Cr-50" : 0.00000094,
           "Cr" :  51.94050623, "Cr-52" : 51.94050623, "Cr_err" : 0.00000063, "Cr-52_err" : 0.00000063,
           "Cr-53" : 52.94064815, "Cr-53_err" : 0.00000062,
           "Cr-54" : 53.93887916, "Cr-54" : 0.00000061,
           "Mn" : 54.93804391, "Mn_err" : 0.00000048,
           "Fe-54" : 53.93960899, "Fe-54_err" : 0.00000053,
           "Fe" : 55.93493633, "Fe-56" : 55.93493633, "Fe_err" : 0.00000049, "Fe-56_err" : 0.00000049,
           "Fe-57" : 56.93539284, "Fe-57" : 0.00000049,
           "Fe-58" :  57.93327443, "Fe-58" : 0.00000053,
           "Ga" : 68.9255735, "Ga-69" : 68.9255735, "Ga_err" : 0.0000013, "Ga-69_err" : 0.0000013,
           "Ga_71" : 70.92470258, "Ga-71_err" : 0.00000087,
           "Ge-70" : 69.92424875, "Ge-70_err" : 0.00000090, 
           "Ge-72" : 71.922075826, "Ge-72_err" : 0.000000081,
           "Ge-73" : 72.923458956, "Ge-73_err" : 0.000000061,
           "Ge" : 73.921177761, "Ge-74" :73.921177761, "Ge_err" : 0.000000013, "Ge-74_err" : .000000013,
           "Ge-76" : 75.921402726, "Ge-76_err" : 0.000000019,
           "Br" : 78.9183376, "Br-79" : 78.9183376, "Br_err" : 0.0000014, "Br-79_err" : 0.0000014, 
           "Br-81" : 80.9162897, "Br-81_err" : 0.0000014,
           "Sr-84" : 83.9134191, "Sr-84_err" : 0.0000013,
           "Sr-86" : 85.9092606, "Sr-86_err" : 0.0000012,
           "Sr-87" : 86.9088775, "Sr-87_err" : 0.0000012,
           "Sr" : 87.9056125, "Sr-88" : 87.9056125, "Sr_err" : 0.0000012, "Sr-88_err" : 0.0000012,
           "I" : 126.9044719, "I_err" : 0.0000039}

# %% [markdown]
# Al - Yes,
# Be - Yes,
# Br - Yes,
# C - Yes,
# Ca - Yes,
# Cl - Yes,
# Cr - Yes
# Cs - NO,
# F - Yes,
# Fe - Yes,
# Ga - Yes,
# Ge - Yes,
# H - Yes,
# He - Yes,
# I - Yes,
# In - NO,
# K - Yes,
# Li - Yes,
# Mg - Yes,
# Mn - Yes,
# N - Yes,
# Na - Yes,
# Nb - NO,
# Ni - NO,
# O - Yes,
# P - Yes,
# Pb - NO,
# Pt - NO,
# S - Yes,
# Sb - NO,
# Si - Yes,
# Sr - Yes,
# V - Yes
# Zn - NO
